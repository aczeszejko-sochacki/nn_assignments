# %% [markdown]
# <a href="https://colab.research.google.com/github/janchorowski/nn_assignments/blob/nn18/assignment4/Assignment4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Starter code: network for Irises in Pytorch
#
#
# In the following cells a feedforward neural network has been implemented with the aid of PyTorch and its autograd mechanism. Please study the code - many network implementations follow a similar pattern.
#
# The provided network trains to nearly 100% accuracy on Iris using Batch Gradient Descent.

# %% [markdown]
# # Assignment 4
#
# **Submission deadline:**
#
# **problems 1-2 last lab session before or on Wednesday, 30.11.18**
#
# **problems 3-8 last lab session before or on Wednesday, 7.12.18**
#
#
# **Points: 11 + 5 bonus points**
#
#
# ## Downloading this notebook
#
# This assignment is an Colab/Jupyter notebook. Download it by cloning https://github.com/janchorowski/nn_assignments. Follow the instructions in its README for instructions.
#
# Please do not hesitate to use GitHub’s pull requests to send us corrections!
#
# If you use Colab please make sure to have a GPU runtime (```Runtime -> Change runtime type -> Hardware Accelarater = GPU```)

# %%
# Please note that this code needs only to be run in a fresh runtime.
# However, it can be rerun afterwards too.
# !pip install -q gdown httpimport
![ -e cifar.npz ] || gdown 'https://drive.google.com/uc?id=1oBzZdtg2zNTPGhbRy6DQ_wrf5L5OAhNR' -O cifar.npz
![ -e mnist.npz ] || gdown 'https://drive.google.com/uc?id=1QPaC3IKB_5tX6yIZgRgkpcqFrfVqPTXU' -O mnist.npz

# http://pytorch.org/
from os.path import exists
from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())
cuda_output = !ldconfig -p|grep cudart.so|sed -e 's/.*\.\([0-9]*\)\.\([0-9]*\)$/cu\1\2/'
accelerator = cuda_output[0] if exists('/dev/nvidia0') else 'cpu'

# !pip install -q http://download.pytorch.org/whl/{accelerator}/torch-0.4.1-{platform}-linux_x86_64.whl torchvision

# %%
import torch

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Getting to know PyTorch
#
# From now on, we will use [pytorch](https://pytorch.org/) to implement neural networks.
#
# Good introductions are the [60-minute tutorial](https://pytorch.org/tutorials/beginner/deep_learning_60min_blitz.html) and [pytorch examples](https://pytorch.org/tutorials/beginner/pytorch_with_examples.html).
#
#
# Pytorch has a set of modules to build neural networks. However, for simplicity, this assignment will use a custom, simple neural network code.

# %%
import numpy as np
import time
import torch
import torch.nn.functional as F


class Layer:
    
    def train_mode(self):
        """Put layer into training mode.
        
        This is useful for e.g. Dropout.
        """
        self.training = True
    
    def eval_mode(self):
        """Put layer into evalation mode.
        
        This is useful for e.g. Dropout.
        """
        self.training = False
    
    def to_device(self, device):
        """Move this layer's parameters to thie given device (cpu/cuda).
        """
        
        pass
    
    @property
    def parameters(self):
        return []
    
    def __repr__(self):
        param_s = ', '.join(['%s%s' % (n, tuple(p.size())) 
                                 for (n,p) in self.parameters])
        if not param_s:
            return '  %s with no params' % (self.__class__.__name__)
        else:
            return '  %s with params: %s' % (self.__class__.__name__, param_s)
    

class AffineLayer(Layer):
    def __init__(self, num_in, num_out):
        self.W = torch.empty(num_in, num_out, dtype=torch.float32, requires_grad=True)
        self.b = torch.empty(1, num_out, dtype=torch.float32, requires_grad=True)
    
    @property
    def parameters(self):
        return [('W', self.W), ('b', self.b)]
    
    def forward(self, x):
        return x.mm(self.W) + self.b
    
    def to_device(self, device):
        with torch.no_grad():
            self.W = self.W.to(device).requires_grad_()
            self.b = self.b.to(device).requires_grad_()

    
class TanhLayer(Layer):
    def forward(self, x):
        return F.tanh(x)

    
class  ReLULayer(Layer):
    def forward(self, x):
        return F.relu(x)


class SoftMaxLayer(Layer):
    def forward(self, x):
        return F.softmax(x, dim=-1)

class CrossEntropyLoss:
    def forward(self, probs, targets):
        return torch.mean(-torch.log(torch.gather(
            probs, 1, targets.unsqueeze(1))))

# %%
class FeedforwardNet(object):
    def __init__(self, layers):
        self.layers = layers
        self.loss_fn = CrossEntropyLoss()

    @property
    def parameters(self):
        params = []
        for layer in self.layers:
            params += layer.parameters
        return params

    @parameters.setter
    def parameters(self, values):
        for (_, ownP), newP in zip(self.parameters, values):
            ownP.data = newP.data
    
    def to_device(self, device):
        for layer in self.layers:
            layer.to_device(device)
    
    def train_mode(self):
        for layer in self.layers:
            layer.train_mode()
    
    def eval_mode(self):
        for layer in self.layers:
            layer.eval_mode()    
    
    def forward(self, x):
        for layer in self.layers:
            x = layer.forward(x)
        return x
    
    def loss(self, outputs, targets):
        return self.loss_fn.forward(outputs, targets)
    
    def __repr__(self):
        strs = ["Feedorward network with %d layers:" % (len(self.layers),)]
        for layer in self.layers:
            strs.append(repr(layer))
        return '\n'.join(strs)

# %%
from sklearn import datasets

iris = datasets.load_iris()
IrisX = iris.data.astype(np.float32)
IrisX = (IrisX - IrisX.mean(axis=0, keepdims=True)) / IrisX.std(axis=0, keepdims=True)
IrisY = iris.target

IrisX = torch.from_numpy(IrisX)
IrisY = torch.from_numpy(IrisY)

# %%
def GD(model, x, y, alpha=1e-4, max_iters=1000000, tolerance=1e-6, device='cpu'):
    """Simple batch gradient descent"""
    x = x.to(device)
    y = y.to(device)
    model.to_device(device)
    try:
        old_loss = np.inf
        model.train_mode()
        tstart = time.time()
        for i in range(max_iters):
            outputs = model.forward(x)
            loss = model.loss(outputs, y)

            loss.backward()
            
            # this disables autograd mechanism and allows us to 
            with torch.torch.no_grad():
                for _, p in model.parameters:
                    p -= p.grad * alpha
                    # Zero gradients for the next iteration
                    p.grad.zero_()

            loss = loss.item()
            if old_loss < loss:
                print("Iter: %d, loss increased!" % (i,))
            if (old_loss - loss) < tolerance:
                print("Tolerance level reached. Exiting.")
                break
            if i % 1000 == 0:
                _, predictions = outputs.data.max(dim=1)
                err_rate = 100.0 * (predictions != y.data).sum() / outputs.size(0)
                print("Iteration {0: >6} | loss {1: >5.2f} | err rate  {2: >5.2f}% | steps/s {3: >5.2f}" \
                      .format(i, loss, err_rate, (1000 if i else 1) / (time.time() - tstart)))
                tstart = time.time()
            old_loss = loss
    except KeyboardInterrupt:
        pass

# %%
model = FeedforwardNet(
    [AffineLayer(4, 10),
     TanhLayer(),
     AffineLayer(10, 3),
     SoftMaxLayer(),
    ])


# Initialize parameters
with torch.torch.no_grad():
    for n, p in model.parameters:
        if n == 'W':
            # p.data.normal_(0, 0.05)
            p.uniform_(-0.1, 0.1)
        elif n == 'b':
            p.zero_()
        else:
            raise ValueError('Unknown parameter name "%s"' % p.name)

# Train
# Iris is so small, that trainingon CPU is faster!
GD(model, IrisX, IrisY, alpha=1e-1, tolerance=1e-7, device='cpu')
# Out:
# /usr/local/lib/python3.6/site-packages/torch/nn/functional.py:995: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# Iteration      0 | loss  1.08 | err rate  39.00% | steps/s 22.36
# Iteration   1000 | loss  0.06 | err rate   2.00% | steps/s 1793.13
# Iteration   2000 | loss  0.04 | err rate   2.00% | steps/s 2213.29
# Iteration   3000 | loss  0.04 | err rate   1.00% | steps/s 2243.11
# Iteration   4000 | loss  0.04 | err rate   1.00% | steps/s 2300.17
# Iteration   5000 | loss  0.04 | err rate   1.00% | steps/s 2245.53
# Iteration   6000 | loss  0.04 | err rate   1.00% | steps/s 2176.47
# Iteration   7000 | loss  0.04 | err rate   1.00% | steps/s 2287.07
# Iteration   8000 | loss  0.04 | err rate   1.00% | steps/s 2174.18
# Iteration   9000 | loss  0.04 | err rate   1.00% | steps/s 2244.92
# Iteration  10000 | loss  0.04 | err rate   1.00% | steps/s 2312.21
# Iteration  11000 | loss  0.04 | err rate   1.00% | steps/s 2198.72
# Iteration  12000 | loss  0.04 | err rate   1.00% | steps/s 2304.94
# Iteration  13000 | loss  0.04 | err rate   1.00% | steps/s 1639.96
# Iteration  14000 | loss  0.04 | err rate   1.00% | steps/s 1280.18
# Iteration  15000 | loss  0.04 | err rate   1.00% | steps/s 1882.82
# Iteration  16000 | loss  0.04 | err rate   1.00% | steps/s 863.64
# Iteration  17000 | loss  0.04 | err rate   1.00% | steps/s 787.11
# Iteration  18000 | loss  0.04 | err rate   1.00% | steps/s 863.74
# Iteration  19000 | loss  0.03 | err rate   1.00% | steps/s 1362.12
# Iteration  20000 | loss  0.03 | err rate   1.00% | steps/s 1409.40
# Iteration  21000 | loss  0.03 | err rate   1.00% | steps/s 1413.08
# Iteration  22000 | loss  0.03 | err rate   1.00% | steps/s 1392.71
# Iteration  23000 | loss  0.03 | err rate   1.00% | steps/s 1325.84
# Iteration  24000 | loss  0.03 | err rate   1.00% | steps/s 1270.21
# Iteration  25000 | loss  0.03 | err rate   1.00% | steps/s 2035.10
# Iteration  26000 | loss  0.03 | err rate   1.00% | steps/s 1635.65
# Iteration  27000 | loss  0.03 | err rate   1.00% | steps/s 2107.85
# Iteration  28000 | loss  0.03 | err rate   1.00% | steps/s 2092.27
# Iteration  29000 | loss  0.03 | err rate   1.00% | steps/s 2150.95
# Iteration  30000 | loss  0.03 | err rate   1.00% | steps/s 2261.21
# Iteration  31000 | loss  0.02 | err rate   1.00% | steps/s 2137.76
# Iteration  32000 | loss  0.02 | err rate   1.00% | steps/s 2284.43
# Iteration  33000 | loss  0.02 | err rate   0.00% | steps/s 2120.36
# Iteration  34000 | loss  0.02 | err rate   0.00% | steps/s 2093.12
# Iteration  35000 | loss  0.02 | err rate   0.00% | steps/s 2288.62
# Iteration  36000 | loss  0.01 | err rate   0.00% | steps/s 2227.73
# Iteration  37000 | loss  0.01 | err rate   0.00% | steps/s 2361.85
# Iteration  38000 | loss  0.01 | err rate   0.00% | steps/s 2381.21
# Iteration  39000 | loss  0.01 | err rate   0.00% | steps/s 2103.40
# Iteration  40000 | loss  0.01 | err rate   0.00% | steps/s 1779.08
# Iteration  41000 | loss  0.01 | err rate   0.00% | steps/s 2329.05
# Iteration  42000 | loss  0.01 | err rate   0.00% | steps/s 1883.15
# Iteration  43000 | loss  0.01 | err rate   0.00% | steps/s 1836.30
# Iteration  44000 | loss  0.01 | err rate   0.00% | steps/s 2130.56
# Iteration  45000 | loss  0.01 | err rate   0.00% | steps/s 2368.75
# Iteration  46000 | loss  0.00 | err rate   0.00% | steps/s 2375.22
# Iteration  47000 | loss  0.00 | err rate   0.00% | steps/s 2335.14
# Iteration  48000 | loss  0.00 | err rate   0.00% | steps/s 1787.13
# Iteration  49000 | loss  0.00 | err rate   0.00% | steps/s 1429.98
# Iteration  50000 | loss  0.00 | err rate   0.00% | steps/s 2326.49
# Iteration  51000 | loss  0.00 | err rate   0.00% | steps/s 1834.03
# Iteration  52000 | loss  0.00 | err rate   0.00% | steps/s 2157.41
# Iteration  53000 | loss  0.00 | err rate   0.00% | steps/s 2320.85
# Iteration  54000 | loss  0.00 | err rate   0.00% | steps/s 2149.95
# Iteration  55000 | loss  0.00 | err rate   0.00% | steps/s 2225.59
# Iteration  56000 | loss  0.00 | err rate   0.00% | steps/s 2350.70
# Iteration  57000 | loss  0.00 | err rate   0.00% | steps/s 2114.78
# Iteration  58000 | loss  0.00 | err rate   0.00% | steps/s 2093.81
# Tolerance level reached. Exiting.

# %% [markdown]
# # Starter code for MNIST and SGD scaffolding

# %%
import os
import torch
import torchvision


batch_size = 128
data_path = './data'

transform = torchvision.transforms.Compose(
    [torchvision.transforms.ToTensor(),
     torchvision.transforms.Normalize((0.1307,), (0.3081,)),
    ])

_test = torchvision.datasets.MNIST(
    data_path, train=False, download=True, transform=transform)

# Load training data, split into train and valid sets
_train = torchvision.datasets.MNIST(
    data_path, train=True, download=True, transform=transform)
_train.train_data = _train.train_data[:50000]
_train.train_labels = _train.train_labels[:50000]

_valid = torchvision.datasets.MNIST(
    data_path, train=True, download=True, transform=transform)
_valid.train_data = _valid.train_data[50000:]
_valid.train_labels = _valid.train_labels[50000:]

mnist_loaders = {
    'train': torch.utils.data.DataLoader(
        _train, batch_size=batch_size, shuffle=True,
        pin_memory=True, num_workers=10),
    'valid': torch.utils.data.DataLoader(
        _valid, batch_size=batch_size, shuffle=False),
    'test': torch.utils.data.DataLoader(
        _test, batch_size=batch_size, shuffle=False)}

# %% [markdown]
# # Problem 1: Stochastic Gradient Descent [3p]
# Implement the following additions to the SGD code provided below (in task 2):
#   1. **[1p]** momentum
#   2. **[1p]** learning rate schedule
#   3. **[1p]** weight decay, in which we additionally minimize for each weight matrix (but typically not the bias) the sum of its elements squared. One way to implement it is to use function `model.parameters` and select all parameters whose names are "`W`" and not "`b`".

# %% [markdown]
# # Problem 2: Tuning the Network for MNIST [4p]
#
# Tune the following network to reach **validation error rate below 1.9%**.
# This should result in a **test error rate below 2%**. To
# tune the network you will need to:
# 1. Choose the number of layers (more than 1, less than 5);
# 2. Choose the number of neurons in each layer (more than 100,
#     less than 5000);
# 3. Pick proper weight initialization;
# 4. Pick proper learning rate schedule (need to decay over time,
#     good range to check on MNIST is about 1e-2 ... 1e-1 at the beginning and
#     half of that after 10000 batches);
# 5. Pick a momentum constant (probably a constant one will be OK).

# %%
from torch.autograd import Variable

# %%
def compute_error_rate(model, data_loader, device='cpu'):
    model.eval_mode()
    num_errs = 0.0
    num_examples = 0
    # we don't need gradient during eval!
    with torch.no_grad():
        for x, y in data_loader:
            x = x.to(device).view(x.size(0), -1)
            y = y.to(device)
            outputs = model.forward(x)
            _, predictions = outputs.data.max(dim=1)
            num_errs += (predictions != y.data).sum().item()
            num_examples += x.size(0)
    return 100.0 * num_errs / num_examples

def SGD(model, data_loaders, alpha=1e-4, num_epochs=1, patience_expansion=1.5,
        log_every=100, device='cpu', weight_decay_rate=0.0005, alpha_decay_rate=0.9995,
        epsilon=0.93):
    model.to_device(device)
    #
    # TODO: Initialize momentum variables
    # Hint: You need one velocity matrix for each parameter
    #
    init_alpha = alpha
    new_alpha = alpha
    tensors = [torch.FloatTensor(param.data.size()).zero_()
               for name, param in model.parameters]
    velocities = [Variable(tensor, requires_grad=False) for tensor in tensors]
    
    iter_ = 0
    epoch = 0
    best_params = None
    best_val_err = np.inf
    history = {'train_losses': [], 'train_errs': [], 'val_errs': []}
    print('Training the model!')
    print('Interrupt at any time to evaluate the best validation model so far.')
    try:
        tstart = time.time()
        siter = iter_
        while epoch < num_epochs:
            model.train_mode()
            epoch += 1
            for x, y in data_loaders['train']:
                x = x.to(device).view(x.size(0), -1)
                y = y.to(device)
                iter_ += 1
                out = model.forward(x)
                loss = model.loss(out, y)
                loss.backward()
                _, predictions = out.max(dim=1)
                err_rate = 100.0 * (predictions != y).sum().item() / out.size(0)

                history['train_losses'].append(loss.item())
                history['train_errs'].append(err_rate)
                
                # disable gradient computations - we do not want torch to
                # backpropagate through the gradient application!
                with torch.no_grad():
                    for (name, p), v in zip(model.parameters, velocities):
                        if name == 'W':
                            # TODO: Implement weight decay addition to gradients
                            p.grad += (weight_decay_rate * p.data)

                        # TODO: Update learning rate
                        # Hint: Use the iteration counter i
                        new_alpha = alpha_decay_rate**iter_ * init_alpha


                        # TODO: Implement velocity update in momentum
                        # lease make sure to modify the contents of v, not the v pointer!!!
                        v.data = epsilon*v.data + (1-epsilon) * p.grad.data

                        # TODO: Set a more sensible learning rule here,
                        #       using your learning rate schedule and momentum
                        p -= new_alpha * v.data
                        # Zero gradients for the next iteration
                        p.grad.zero_()

                if iter_ % log_every == 0:
                    num_iter = iter_ - siter + 1
                    print("Minibatch {0: >6}  | loss {1: >5.2f} | err rate {2: >5.2f}%, steps/s {3: >5.2f}" \
                          .format(iter_, loss.item(), err_rate, num_iter / (time.time() - tstart)))
                    tstart = time.time()
                           
            
            val_err_rate = compute_error_rate(model, data_loaders['valid'], device)
            history['val_errs'].append((iter_, val_err_rate))
            
            if val_err_rate < best_val_err:
                # Adjust num of epochs
                num_epochs = int(np.maximum(num_epochs, epoch * patience_expansion + 1))
                best_epoch = epoch
                best_val_err = val_err_rate
                best_params = [p.detach().cpu() for (_, p) in model.parameters]
            m = "After epoch {0: >2} | valid err rate: {1: >5.2f}% | doing {2: >3} epochs" \
                .format(epoch, val_err_rate, num_epochs)
            print('{0}\n{1}\n{0}'.format('-' * len(m), m))

    except KeyboardInterrupt:
        pass
    if best_params is not None:
        print("\nLoading best params on validation set (epoch %d)\n" %(best_epoch))
        model.parameters = best_params
    plot_history(history)

def plot_history(history):
    figsize(16, 4)
    subplot(1,2,1)
    train_loss = np.array(history['train_losses'])
    semilogy(np.arange(train_loss.shape[0]), train_loss, label='batch train loss')
    legend()
        
    subplot(1,2,2)
    train_errs = np.array(history['train_errs'])
    plot(np.arange(train_errs.shape[0]), train_errs, label='batch train error rate')
    val_errs = np.array(history['val_errs'])
    plot(val_errs[:,0], val_errs[:,1], label='validation error rate', color='r')
    ylim(0,20)
    legend()

# %%
#
# TODO: Pick a network architecture here.
#       The one below is just softmax regression.
#
n_hidden_1 = 700
n_hidden_2 = 600

model = FeedforwardNet(
    [
     AffineLayer(784, n_hidden_1),
     ReLULayer(),
     AffineLayer(n_hidden_1, n_hidden_2),
     ReLULayer(),
     AffineLayer(n_hidden_2, 10),
     SoftMaxLayer()
    ])


with torch.no_grad():
    # Initialize parameters
    for name, p in model.parameters:
        if name == 'W':
            # Xavier initialization
#             relu_xavier_variance = np.sqrt(2) * np.sqrt(2 / (784 + 10))
#             p.normal_(0, relu_xavier_variance)
            relu_xavier_border = np.sqrt(2) * np.sqrt(6 / (784 + 10))
            p.data.uniform_(-relu_xavier_border, relu_xavier_border)
        elif name == 'b':
            p.zero_()
        else:
            raise ValueError('Unknown parameter name "%s"' % p.name)

# On GPU enabled devices set device='cuda' else set device='cpu'
SGD(model, mnist_loaders, alpha=5*1e-1, device='cpu')

print("Test error rate: %.2f%%" % compute_error_rate(model, mnist_loaders['test']))
# Out:
# Training the model!
# Interrupt at any time to evaluate the best validation model so far.
# Minibatch    100  | loss  0.24 | err rate  8.59%, steps/s 40.07
# Minibatch    200  | loss  0.11 | err rate  1.56%, steps/s 101.00
# Minibatch    300  | loss  0.19 | err rate  5.47%, steps/s 150.06
# ----------------------------------------------------------
# After epoch  1 | valid err rate:  3.06% | doing   2 epochs
# ----------------------------------------------------------
# Minibatch    400  | loss  0.05 | err rate  1.56%, steps/s 111.85
# Minibatch    500  | loss  0.03 | err rate  1.56%, steps/s 247.24
# Minibatch    600  | loss  0.09 | err rate  3.12%, steps/s 298.07
# Minibatch    700  | loss  0.05 | err rate  1.56%, steps/s 355.76
# ----------------------------------------------------------
# After epoch  2 | valid err rate:  2.25% | doing   4 epochs
# ----------------------------------------------------------
# Minibatch    800  | loss  0.02 | err rate  0.00%, steps/s 223.93
# Minibatch    900  | loss  0.02 | err rate  0.00%, steps/s 447.08
# Minibatch   1000  | loss  0.04 | err rate  2.34%, steps/s 493.23
# Minibatch   1100  | loss  0.04 | err rate  0.78%, steps/s 542.91
# ----------------------------------------------------------
# After epoch  3 | valid err rate:  2.07% | doing   5 epochs
# ----------------------------------------------------------
# Minibatch   1200  | loss  0.03 | err rate  0.78%, steps/s 293.91
# Minibatch   1300  | loss  0.01 | err rate  0.00%, steps/s 544.28
# Minibatch   1400  | loss  0.03 | err rate  0.78%, steps/s 600.47
# Minibatch   1500  | loss  0.01 | err rate  0.00%, steps/s 630.96
# ----------------------------------------------------------
# After epoch  4 | valid err rate:  2.00% | doing   7 epochs
# ----------------------------------------------------------
# Minibatch   1600  | loss  0.01 | err rate  0.00%, steps/s 388.45
# Minibatch   1700  | loss  0.01 | err rate  0.00%, steps/s 702.20
# Minibatch   1800  | loss  0.01 | err rate  0.00%, steps/s 765.77
# Minibatch   1900  | loss  0.01 | err rate  0.78%, steps/s 790.46
# ----------------------------------------------------------
# After epoch  5 | valid err rate:  1.95% | doing   8 epochs
# ----------------------------------------------------------
# Minibatch   2000  | loss  0.01 | err rate  0.00%, steps/s 478.64
# Minibatch   2100  | loss  0.01 | err rate  0.00%, steps/s 868.11
# Minibatch   2200  | loss  0.03 | err rate  1.56%, steps/s 895.81
# Minibatch   2300  | loss  0.02 | err rate  0.78%, steps/s 947.73
# ----------------------------------------------------------
# After epoch  6 | valid err rate:  1.78% | doing  10 epochs
# ----------------------------------------------------------
# Minibatch   2400  | loss  0.01 | err rate  0.00%, steps/s 570.93
# Minibatch   2500  | loss  0.02 | err rate  0.00%, steps/s 1028.95
# Minibatch   2600  | loss  0.00 | err rate  0.00%, steps/s 1072.62
# Minibatch   2700  | loss  0.01 | err rate  0.00%, steps/s 1114.69
# ----------------------------------------------------------
# After epoch  7 | valid err rate:  1.75% | doing  11 epochs
# ----------------------------------------------------------
# Minibatch   2800  | loss  0.00 | err rate  0.00%, steps/s 637.16
# Minibatch   2900  | loss  0.01 | err rate  0.00%, steps/s 971.33
# Minibatch   3000  | loss  0.00 | err rate  0.00%, steps/s 1164.26
# Minibatch   3100  | loss  0.01 | err rate  0.00%, steps/s 1237.66
# ----------------------------------------------------------
# After epoch  8 | valid err rate:  1.75% | doing  11 epochs
# ----------------------------------------------------------
# Minibatch   3200  | loss  0.01 | err rate  0.00%, steps/s 668.74
# Minibatch   3300  | loss  0.01 | err rate  0.00%, steps/s 966.90
# Minibatch   3400  | loss  0.01 | err rate  0.00%, steps/s 1406.18
# Minibatch   3500  | loss  0.01 | err rate  0.00%, steps/s 1459.71
# ----------------------------------------------------------
# After epoch  9 | valid err rate:  1.80% | doing  11 epochs
# ----------------------------------------------------------
# Minibatch   3600  | loss  0.01 | err rate  0.00%, steps/s 858.19
# Minibatch   3700  | loss  0.01 | err rate  0.00%, steps/s 1533.45
# Minibatch   3800  | loss  0.01 | err rate  0.00%, steps/s 1555.38
# Minibatch   3900  | loss  0.01 | err rate  0.00%, steps/s 1651.07
# ----------------------------------------------------------
# After epoch 10 | valid err rate:  1.71% | doing  16 epochs
# ----------------------------------------------------------
# Minibatch   4000  | loss  0.01 | err rate  0.78%, steps/s 930.79
# Minibatch   4100  | loss  0.01 | err rate  0.00%, steps/s 1704.85
# Minibatch   4200  | loss  0.01 | err rate  0.00%, steps/s 1751.57
# Minibatch   4300  | loss  0.00 | err rate  0.00%, steps/s 1909.57
# ----------------------------------------------------------
# After epoch 11 | valid err rate:  1.70% | doing  17 epochs
# ----------------------------------------------------------
# Minibatch   4400  | loss  0.01 | err rate  0.00%, steps/s 1034.88
# Minibatch   4500  | loss  0.01 | err rate  0.00%, steps/s 1867.90
# Minibatch   4600  | loss  0.00 | err rate  0.00%, steps/s 1907.04
# ----------------------------------------------------------
# After epoch 12 | valid err rate:  1.72% | doing  17 epochs
# ----------------------------------------------------------
# Minibatch   4700  | loss  0.01 | err rate  0.00%, steps/s 1111.46
# Minibatch   4800  | loss  0.01 | err rate  0.00%, steps/s 1991.01
# Minibatch   4900  | loss  0.01 | err rate  0.00%, steps/s 1781.36
# Minibatch   5000  | loss  0.01 | err rate  0.00%, steps/s 2090.82
# ----------------------------------------------------------
# After epoch 13 | valid err rate:  1.70% | doing  17 epochs
# ----------------------------------------------------------
# Minibatch   5100  | loss  0.00 | err rate  0.00%, steps/s 1208.21
# Minibatch   5200  | loss  0.01 | err rate  0.00%, steps/s 2181.83
# Minibatch   5300  | loss  0.00 | err rate  0.00%, steps/s 2153.05
# Minibatch   5400  | loss  0.01 | err rate  0.00%, steps/s 2206.33
# ----------------------------------------------------------
# After epoch 14 | valid err rate:  1.76% | doing  17 epochs
# ----------------------------------------------------------
# Minibatch   5500  | loss  0.00 | err rate  0.00%, steps/s 1319.21
# Minibatch   5600  | loss  0.01 | err rate  0.00%, steps/s 2239.79
# Minibatch   5700  | loss  0.01 | err rate  0.00%, steps/s 2358.03
# Minibatch   5800  | loss  0.01 | err rate  0.00%, steps/s 2368.02
# ----------------------------------------------------------
# After epoch 15 | valid err rate:  1.74% | doing  17 epochs
# ----------------------------------------------------------
# Minibatch   5900  | loss  0.00 | err rate  0.00%, steps/s 1440.02
# Minibatch   6000  | loss  0.01 | err rate  0.00%, steps/s 2476.41
# Minibatch   6100  | loss  0.01 | err rate  0.00%, steps/s 2373.86
# Minibatch   6200  | loss  0.00 | err rate  0.00%, steps/s 2661.02
# ----------------------------------------------------------
# After epoch 16 | valid err rate:  1.71% | doing  17 epochs
# ----------------------------------------------------------
# Minibatch   6300  | loss  0.00 | err rate  0.00%, steps/s 1524.86
# Minibatch   6400  | loss  0.00 | err rate  0.00%, steps/s 2719.13
# Minibatch   6500  | loss  0.01 | err rate  0.00%, steps/s 2625.80
# Minibatch   6600  | loss  0.01 | err rate  0.00%, steps/s 2712.58
# ----------------------------------------------------------
# After epoch 17 | valid err rate:  1.74% | doing  17 epochs
# ----------------------------------------------------------
#
# Loading best params on validation set (epoch 11)
#
# Test error rate: 1.83%

# %% [markdown]
# # Problem 3: Dropout [2p]
#
# Implement a **dropout** layer and try to train a
# network getting below 1.5% test error rates with dropout. The best
# results with dropout are below 1%!
#
# Remember to turn off dropout during testing, using `model.train_mode()` and `model.eval_mode()`!
#
# Hint: Use [torch.nn.functional.dropout](http://pytorch.org/docs/master/nn.html#torch.nn.functional.dropout).
#
# Details: http://arxiv.org/pdf/1207.0580.pdf.

# %%
class DropoutLayer(Layer):
    def __init__(self, p=0.5, inplace=False):
        self.p = p
        self.inplace = inplace
        
    def forward(self, x):
        return F.dropout(x, self.p, self.training, self.inplace)

# %%
n_hidden_1 = 750
n_hidden_2 = 600
prob_1 = 0.295
prob_2 = 0.265

model_drop = FeedforwardNet([
    AffineLayer(784, n_hidden_1),
    DropoutLayer(p=prob_1),
    ReLULayer(),
    AffineLayer(n_hidden_1, n_hidden_2),
    DropoutLayer(p=prob_2),
    ReLULayer(),
    AffineLayer(n_hidden_2, 10),
    SoftMaxLayer()
])


with torch.no_grad():
    # Initialize parameters
    for name, p in model_drop.parameters:
        if name == 'W':
            # Xavier initialization
            relu_xavier_variance = np.sqrt(2) * np.sqrt(2 / (784 + 10))
            p.normal_(0, relu_xavier_variance)
#             relu_xavier_border = np.sqrt(2) * np.sqrt(6 / (784 + 10))
#             p.data.uniform_(-relu_xavier_border, relu_xavier_border)
        elif name == 'b':
            p.zero_()
        else:
            raise ValueError('Unknown parameter name "%s"' % p.name)

# On GPU enabled devices set device='cuda' else set device='cpu'
SGD(model_drop, mnist_loaders, alpha=5*1e-1, device='cpu', weight_decay_rate=0.0005,
    alpha_decay_rate=0.99965, epsilon=0.929)

print("Test error rate: %.2f%%" % compute_error_rate(model_drop, mnist_loaders['test']))
# Out:
# Training the model!
# Interrupt at any time to evaluate the best validation model so far.
# Minibatch    100  | loss  0.50 | err rate 11.72%, steps/s 38.16
# Minibatch    200  | loss  0.22 | err rate  6.25%, steps/s 92.40
# Minibatch    300  | loss  0.19 | err rate  7.03%, steps/s 144.38
# ----------------------------------------------------------
# After epoch  1 | valid err rate:  3.41% | doing   2 epochs
# ----------------------------------------------------------
# Minibatch    400  | loss  0.17 | err rate  3.91%, steps/s 107.47
# Minibatch    500  | loss  0.25 | err rate  7.03%, steps/s 235.50
# Minibatch    600  | loss  0.16 | err rate  5.47%, steps/s 272.84
# Minibatch    700  | loss  0.08 | err rate  3.12%, steps/s 321.75
# ----------------------------------------------------------
# After epoch  2 | valid err rate:  2.77% | doing   4 epochs
# ----------------------------------------------------------
# Minibatch    800  | loss  0.11 | err rate  2.34%, steps/s 216.80
# Minibatch    900  | loss  0.04 | err rate  0.78%, steps/s 420.24
# Minibatch   1000  | loss  0.11 | err rate  1.56%, steps/s 468.00
# Minibatch   1100  | loss  0.11 | err rate  3.12%, steps/s 338.15
# ----------------------------------------------------------
# After epoch  3 | valid err rate:  2.22% | doing   5 epochs
# ----------------------------------------------------------
# Minibatch   1200  | loss  0.10 | err rate  2.34%, steps/s 225.03
# Minibatch   1300  | loss  0.08 | err rate  2.34%, steps/s 464.83
# Minibatch   1400  | loss  0.06 | err rate  2.34%, steps/s 550.46
# Minibatch   1500  | loss  0.12 | err rate  3.91%, steps/s 502.97
# ----------------------------------------------------------
# After epoch  4 | valid err rate:  2.31% | doing   5 epochs
# ----------------------------------------------------------
# Minibatch   1600  | loss  0.07 | err rate  2.34%, steps/s 384.36
# Minibatch   1700  | loss  0.10 | err rate  1.56%, steps/s 671.87
# Minibatch   1800  | loss  0.06 | err rate  2.34%, steps/s 704.12
# Minibatch   1900  | loss  0.04 | err rate  0.78%, steps/s 695.49
# ----------------------------------------------------------
# After epoch  5 | valid err rate:  2.20% | doing   8 epochs
# ----------------------------------------------------------
# Minibatch   2000  | loss  0.10 | err rate  3.91%, steps/s 477.46
# Minibatch   2100  | loss  0.02 | err rate  0.00%, steps/s 835.89
# Minibatch   2200  | loss  0.04 | err rate  0.78%, steps/s 871.46
# Minibatch   2300  | loss  0.10 | err rate  3.12%, steps/s 912.61
# ----------------------------------------------------------
# After epoch  6 | valid err rate:  1.94% | doing  10 epochs
# ----------------------------------------------------------
# Minibatch   2400  | loss  0.06 | err rate  1.56%, steps/s 566.57
# Minibatch   2500  | loss  0.11 | err rate  3.12%, steps/s 985.09
# Minibatch   2600  | loss  0.04 | err rate  1.56%, steps/s 1006.44
# Minibatch   2700  | loss  0.06 | err rate  3.12%, steps/s 1091.58
# ----------------------------------------------------------
# After epoch  7 | valid err rate:  1.89% | doing  11 epochs
# ----------------------------------------------------------
# Minibatch   2800  | loss  0.07 | err rate  1.56%, steps/s 670.19
# Minibatch   2900  | loss  0.07 | err rate  2.34%, steps/s 1132.85
# Minibatch   3000  | loss  0.06 | err rate  3.12%, steps/s 1178.95
# Minibatch   3100  | loss  0.08 | err rate  3.12%, steps/s 1202.81
# ----------------------------------------------------------
# After epoch  8 | valid err rate:  1.88% | doing  13 epochs
# ----------------------------------------------------------
# Minibatch   3200  | loss  0.06 | err rate  1.56%, steps/s 767.77
# Minibatch   3300  | loss  0.01 | err rate  0.00%, steps/s 1281.49
# Minibatch   3400  | loss  0.03 | err rate  0.78%, steps/s 1342.39
# Minibatch   3500  | loss  0.07 | err rate  1.56%, steps/s 1418.43
# ----------------------------------------------------------
# After epoch  9 | valid err rate:  1.75% | doing  14 epochs
# ----------------------------------------------------------
# Minibatch   3600  | loss  0.05 | err rate  3.12%, steps/s 845.06
# Minibatch   3700  | loss  0.04 | err rate  1.56%, steps/s 1381.72
# Minibatch   3800  | loss  0.07 | err rate  2.34%, steps/s 986.40
# Minibatch   3900  | loss  0.04 | err rate  0.78%, steps/s 1442.46
# ----------------------------------------------------------
# After epoch 10 | valid err rate:  1.75% | doing  14 epochs
# ----------------------------------------------------------
# Minibatch   4000  | loss  0.01 | err rate  0.00%, steps/s 930.99
# Minibatch   4100  | loss  0.03 | err rate  0.78%, steps/s 1456.35
# Minibatch   4200  | loss  0.01 | err rate  0.78%, steps/s 1567.06
# Minibatch   4300  | loss  0.07 | err rate  3.12%, steps/s 1705.36
# ----------------------------------------------------------
# After epoch 11 | valid err rate:  1.65% | doing  17 epochs
# ----------------------------------------------------------
# Minibatch   4400  | loss  0.02 | err rate  0.78%, steps/s 963.53
# Minibatch   4500  | loss  0.03 | err rate  0.78%, steps/s 1851.59
# Minibatch   4600  | loss  0.05 | err rate  1.56%, steps/s 1869.00
# ----------------------------------------------------------
# After epoch 12 | valid err rate:  1.69% | doing  17 epochs
# ----------------------------------------------------------
# Minibatch   4700  | loss  0.02 | err rate  0.78%, steps/s 1087.74
# Minibatch   4800  | loss  0.01 | err rate  0.00%, steps/s 1847.22
# Minibatch   4900  | loss  0.01 | err rate  0.00%, steps/s 1927.53
# Minibatch   5000  | loss  0.05 | err rate  3.12%, steps/s 1986.47
# ----------------------------------------------------------
# After epoch 13 | valid err rate:  1.64% | doing  20 epochs
# ----------------------------------------------------------
# Minibatch   5100  | loss  0.03 | err rate  1.56%, steps/s 1172.98
# Minibatch   5200  | loss  0.04 | err rate  1.56%, steps/s 2095.34
# Minibatch   5300  | loss  0.03 | err rate  0.78%, steps/s 2061.84
# Minibatch   5400  | loss  0.03 | err rate  0.78%, steps/s 2117.54
# ----------------------------------------------------------
# After epoch 14 | valid err rate:  1.66% | doing  20 epochs
# ----------------------------------------------------------
# Minibatch   5500  | loss  0.03 | err rate  0.78%, steps/s 1314.78
# Minibatch   5600  | loss  0.04 | err rate  1.56%, steps/s 2238.33
# Minibatch   5700  | loss  0.01 | err rate  0.00%, steps/s 2315.75
# Minibatch   5800  | loss  0.02 | err rate  0.78%, steps/s 2335.57
# ----------------------------------------------------------
# After epoch 15 | valid err rate:  1.68% | doing  20 epochs
# ----------------------------------------------------------
# Minibatch   5900  | loss  0.05 | err rate  1.56%, steps/s 1381.17
# Minibatch   6000  | loss  0.02 | err rate  0.78%, steps/s 2336.86
# Minibatch   6100  | loss  0.01 | err rate  0.00%, steps/s 2392.70
# Minibatch   6200  | loss  0.01 | err rate  0.00%, steps/s 2263.29
# ----------------------------------------------------------
# After epoch 16 | valid err rate:  1.71% | doing  20 epochs
# ----------------------------------------------------------
# Minibatch   6300  | loss  0.03 | err rate  0.78%, steps/s 1491.42
# Minibatch   6400  | loss  0.03 | err rate  0.78%, steps/s 2451.47
# Minibatch   6500  | loss  0.03 | err rate  0.78%, steps/s 2572.04
# Minibatch   6600  | loss  0.01 | err rate  0.00%, steps/s 2596.42
# ----------------------------------------------------------
# After epoch 17 | valid err rate:  1.63% | doing  26 epochs
# ----------------------------------------------------------
# Minibatch   6700  | loss  0.01 | err rate  0.00%, steps/s 1554.57
# Minibatch   6800  | loss  0.05 | err rate  0.78%, steps/s 2712.10
# Minibatch   6900  | loss  0.02 | err rate  0.00%, steps/s 2693.84
# Minibatch   7000  | loss  0.03 | err rate  0.78%, steps/s 2755.46
# ----------------------------------------------------------
# After epoch 18 | valid err rate:  1.63% | doing  26 epochs
# ----------------------------------------------------------
# Minibatch   7100  | loss  0.01 | err rate  0.00%, steps/s 1654.62
# Minibatch   7200  | loss  0.06 | err rate  2.34%, steps/s 2726.61
# Minibatch   7300  | loss  0.03 | err rate  1.56%, steps/s 2877.71
# Minibatch   7400  | loss  0.01 | err rate  0.00%, steps/s 2618.86
# ----------------------------------------------------------
# After epoch 19 | valid err rate:  1.63% | doing  26 epochs
# ----------------------------------------------------------
# Minibatch   7500  | loss  0.03 | err rate  0.78%, steps/s 1777.27
# Minibatch   7600  | loss  0.01 | err rate  0.78%, steps/s 2985.86
# Minibatch   7700  | loss  0.01 | err rate  0.00%, steps/s 2587.04
# Minibatch   7800  | loss  0.02 | err rate  0.78%, steps/s 3024.23
# ----------------------------------------------------------
# After epoch 20 | valid err rate:  1.59% | doing  31 epochs
# ----------------------------------------------------------
# Minibatch   7900  | loss  0.01 | err rate  0.78%, steps/s 1741.21
# Minibatch   8000  | loss  0.02 | err rate  0.78%, steps/s 3095.75
# Minibatch   8100  | loss  0.01 | err rate  0.00%, steps/s 2806.94
# Minibatch   8200  | loss  0.03 | err rate  0.78%, steps/s 3134.78
# ----------------------------------------------------------
# After epoch 21 | valid err rate:  1.58% | doing  32 epochs
# ----------------------------------------------------------
# Minibatch   8300  | loss  0.02 | err rate  0.78%, steps/s 1730.78
# Minibatch   8400  | loss  0.02 | err rate  0.78%, steps/s 2914.86
# Minibatch   8500  | loss  0.01 | err rate  0.00%, steps/s 3222.37
# Minibatch   8600  | loss  0.02 | err rate  0.78%, steps/s 3469.13
# ----------------------------------------------------------
# After epoch 22 | valid err rate:  1.58% | doing  32 epochs
# ----------------------------------------------------------
# Minibatch   8700  | loss  0.01 | err rate  0.00%, steps/s 2013.46
# Minibatch   8800  | loss  0.02 | err rate  0.78%, steps/s 3467.45
# Minibatch   8900  | loss  0.02 | err rate  1.56%, steps/s 3516.00
# ----------------------------------------------------------
# After epoch 23 | valid err rate:  1.57% | doing  35 epochs
# ----------------------------------------------------------
# Minibatch   9000  | loss  0.02 | err rate  0.78%, steps/s 2101.01
# Minibatch   9100  | loss  0.01 | err rate  0.00%, steps/s 3528.62
# Minibatch   9200  | loss  0.01 | err rate  0.00%, steps/s 3615.41
# Minibatch   9300  | loss  0.02 | err rate  0.78%, steps/s 3620.47
# ----------------------------------------------------------
# After epoch 24 | valid err rate:  1.58% | doing  35 epochs
# ----------------------------------------------------------
# Minibatch   9400  | loss  0.02 | err rate  0.78%, steps/s 2190.29
# Minibatch   9500  | loss  0.02 | err rate  0.78%, steps/s 3717.47
# Minibatch   9600  | loss  0.01 | err rate  0.00%, steps/s 3809.77
# Minibatch   9700  | loss  0.02 | err rate  0.00%, steps/s 3772.19
# ----------------------------------------------------------
# After epoch 25 | valid err rate:  1.61% | doing  35 epochs
# ----------------------------------------------------------
# Minibatch   9800  | loss  0.01 | err rate  0.00%, steps/s 2278.98
# Minibatch   9900  | loss  0.01 | err rate  0.00%, steps/s 3968.51
# Minibatch  10000  | loss  0.02 | err rate  0.00%, steps/s 3874.38
# Minibatch  10100  | loss  0.04 | err rate  1.56%, steps/s 3944.25
# ----------------------------------------------------------
# After epoch 26 | valid err rate:  1.65% | doing  35 epochs
# ----------------------------------------------------------
# Minibatch  10200  | loss  0.00 | err rate  0.00%, steps/s 2358.49
# Minibatch  10300  | loss  0.01 | err rate  0.00%, steps/s 4037.11
# Minibatch  10400  | loss  0.01 | err rate  0.00%, steps/s 4056.93
# Minibatch  10500  | loss  0.01 | err rate  0.00%, steps/s 3938.64
# ----------------------------------------------------------
# After epoch 27 | valid err rate:  1.58% | doing  35 epochs
# ----------------------------------------------------------
# Minibatch  10600  | loss  0.03 | err rate  0.78%, steps/s 2467.24
# Minibatch  10700  | loss  0.01 | err rate  0.00%, steps/s 4197.82
# Minibatch  10800  | loss  0.01 | err rate  0.00%, steps/s 4228.05
# Minibatch  10900  | loss  0.01 | err rate  0.00%, steps/s 4228.32
# ----------------------------------------------------------
# After epoch 28 | valid err rate:  1.61% | doing  35 epochs
# ----------------------------------------------------------
# Minibatch  11000  | loss  0.00 | err rate  0.00%, steps/s 2331.94
# Minibatch  11100  | loss  0.02 | err rate  0.00%, steps/s 4369.10
# Minibatch  11200  | loss  0.01 | err rate  0.00%, steps/s 4335.98
# Minibatch  11300  | loss  0.05 | err rate  1.56%, steps/s 4399.41
# ----------------------------------------------------------
# After epoch 29 | valid err rate:  1.65% | doing  35 epochs
# ----------------------------------------------------------
# Minibatch  11400  | loss  0.02 | err rate  0.78%, steps/s 2642.04
# Minibatch  11500  | loss  0.01 | err rate  0.00%, steps/s 4374.27
# Minibatch  11600  | loss  0.01 | err rate  0.00%, steps/s 4567.19
# Minibatch  11700  | loss  0.03 | err rate  0.78%, steps/s 4125.71
# ----------------------------------------------------------
# After epoch 30 | valid err rate:  1.65% | doing  35 epochs
# ----------------------------------------------------------
# Minibatch  11800  | loss  0.02 | err rate  0.78%, steps/s 2794.36
# Minibatch  11900  | loss  0.02 | err rate  0.78%, steps/s 4601.46
# Minibatch  12000  | loss  0.01 | err rate  0.00%, steps/s 4671.13
# Minibatch  12100  | loss  0.02 | err rate  0.00%, steps/s 4771.69
# ----------------------------------------------------------
# After epoch 31 | valid err rate:  1.64% | doing  35 epochs
# ----------------------------------------------------------
# Minibatch  12200  | loss  0.02 | err rate  0.78%, steps/s 2851.40
# Minibatch  12300  | loss  0.02 | err rate  0.78%, steps/s 4753.35
# Minibatch  12400  | loss  0.02 | err rate  0.00%, steps/s 4790.96
# Minibatch  12500  | loss  0.00 | err rate  0.00%, steps/s 5027.47
# ----------------------------------------------------------
# After epoch 32 | valid err rate:  1.63% | doing  35 epochs
# ----------------------------------------------------------
# Minibatch  12600  | loss  0.04 | err rate  1.56%, steps/s 2929.36
# Minibatch  12700  | loss  0.03 | err rate  0.78%, steps/s 4980.87
# Minibatch  12800  | loss  0.02 | err rate  0.78%, steps/s 4974.27
# Minibatch  12900  | loss  0.02 | err rate  0.78%, steps/s 5283.64
# ----------------------------------------------------------
# After epoch 33 | valid err rate:  1.66% | doing  35 epochs
# ----------------------------------------------------------
# Minibatch  13000  | loss  0.03 | err rate  1.56%, steps/s 2963.63
# Minibatch  13100  | loss  0.01 | err rate  0.00%, steps/s 5158.99
# Minibatch  13200  | loss  0.02 | err rate  0.00%, steps/s 5193.74
# ----------------------------------------------------------
# After epoch 34 | valid err rate:  1.61% | doing  35 epochs
# ----------------------------------------------------------
# Minibatch  13300  | loss  0.01 | err rate  0.00%, steps/s 3125.37
# Minibatch  13400  | loss  0.01 | err rate  0.00%, steps/s 5336.64
# Minibatch  13500  | loss  0.02 | err rate  0.00%, steps/s 5236.34
# Minibatch  13600  | loss  0.01 | err rate  0.00%, steps/s 5308.66
# ----------------------------------------------------------
# After epoch 35 | valid err rate:  1.64% | doing  35 epochs
# ----------------------------------------------------------
#
# Loading best params on validation set (epoch 23)
#
# Test error rate: 1.48%

# %% [markdown]
# # Problem 4: Data Augmentation [1p]
#
# Apply data augmentation methods (e.g. rotations, noise, crops) when training networks on MNIST, to significantly reduce test error rate for your network. You can use functions from the [torchvision.transforms](http://pytorch.org/docs/master/torchvision/transforms.html) module.

# %%
from torchvision import transforms

# %%
# Apply new transforms to the combined transforms
transform = torchvision.transforms.Compose([
    torchvision.transforms.RandomRotation((0, 360))
#     torchvision.transforms.CentralCrop(),
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize((0.1307,), (0.3081,)),
])

_test = torchvision.datasets.MNIST(
    data_path, train=False, download=True, transform=transform)

# Load training data, split into train and valid sets
_train = torchvision.datasets.MNIST(
    data_path, train=True, download=True, transform=transform)
_train.train_data = _train.train_data[:50000]
_train.train_labels = _train.train_labels[:50000]

_valid = torchvision.datasets.MNIST(
    data_path, train=True, download=True, transform=transform)
_valid.train_data = _valid.train_data[50000:]
_valid.train_labels = _valid.train_labels[50000:]

mnist_loaders = {
    'train': torch.utils.data.DataLoader(
        _train, batch_size=batch_size, shuffle=True,
        pin_memory=True, num_workers=10),
    'valid': torch.utils.data.DataLoader(
        _valid, batch_size=batch_size, shuffle=False),
    'test': torch.utils.data.DataLoader(
        _test, batch_size=batch_size, shuffle=False)}

# %% [markdown]
# # Problem 5: Batch Normalization [1p]
#
# *Covariate shift* is a phenomenon associated with training deep models. Simply put, weight changes in early layers cause major changes in distribution of inputs to later layers, making it difficult to train later layers.
#
# [Batch Normalization](https://arxiv.org/abs/1502.03167) addresses this problem by normalizing distributions of inputs to layers within mini-batches. It typically allows to train networks faster and/or with higher learning rates, lessens the importance
# of initialization and might eliminate the need for Dropout.
#
# Implement Batch Normalization and compare with regular training of MNIST models.
#
# Remember to use the batch statistics during model training and to use an average of training batch statistics during model evaluation. For details please consult the paper.

# %% [markdown]
# # Problem 6: Norm Constraints [1p bonus]
#
# Implement norm constraints, i.e. instead of weight decay, that tries to set
# all weights to small values, apply a limit on the total
# norm of connections incoming to a neuron. In our case, this
# corresponds to clipping the norm of *rows* of weight
# matrices. An easy way of implementing it is to make a gradient
# step, then look at the norm of rows and scale down those that are
# over the threshold (this technique is called "projected gradient descent").
#
# Please consult the Dropout paper (http://arxiv.org/pdf/1207.0580.pdf) for details.

# %% [markdown]
# # Problem 6: Polyak Averaging [1p bonus]
#
# Implement Polyak averaging. For each parameter $\theta$
# keep a separate, exponentially decayed average of the past values
# $$
# \bar{\theta}_n = \alpha_p\bar{\theta}_{n-1} + (1-\alpha_p)\theta_n.
# $$
# Use that average when evaluating the model on the test set.
# Validate the approach by training a model on the MNIST dataset.

# %% [markdown]
# # Problem 7: Convolutional Network [2p bonus]
#
# Use convolutional and max-pooling layers (`torch.nn.functional.conv2d`, `torch.nn.functional.max_pool2d`) and (without dropout) get a test error rate below 1.5%.

# %% [markdown]
# # Problem 8: Hyperparameter tuner [1p bonus]
#
# Implement a hyper-parameter tuner able to optimize the learing rate schedule, number of neurons and similar hyperparameters. For start, use random search (please see http://jmlr.csail.mit.edu/papers/volume13/bergstra12a/bergstra12a.pdf and especially Fig 1. for intuitions on why random search is better than grid search). It may be a good idea to use a fixed maximum number of epochs (or training time) for each optimization trial to prevent selecting hyperparameters that yield slowly converging solutions. A good result will be a set of hyperparameters that reach on MNIST solutions with test errors less than $1.3\%$ in no more than 50 epochs.
